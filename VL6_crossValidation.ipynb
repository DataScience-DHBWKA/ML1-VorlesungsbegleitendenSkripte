# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, f1_score, roc_curve, roc_auc_score, mean_squared_error, r2_score, classification_report
from sklearn.pipeline import make_pipeline

from ISLP import load_data
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn import datasets
from matplotlib.colors import ListedColormap

# %%
Smarket = load_data('Smarket')
Smarket
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %% [markdown]
# ## Cross Validation um k zu bestimmen
# Smarket Datensatz und KNN

# %%
X = Smarket.drop('Direction', axis=1)

# Skalierung der Inputdaten
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

y = Smarket[['Direction']].values.ravel()

# Split in training and testing set
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Pipeline erstellen (mit StandardScaler und KNN)
pipeline = make_pipeline(StandardScaler(), KNeighborsClassifier())

# Parameter für GridSearch (verschiedene Werte von k testen)
param_grid = {'kneighborsclassifier__n_neighbors': range(1, 25)}

# GridSearchCV mit Cross-Validation erstellen (z.B. 5-fache Cross-Validation)
grid_search = GridSearchCV(pipeline, param_grid, cv=5)

# Modell mit den Trainingsdaten fitten
grid_search.fit(X_train, y_train)

# Den besten Wert von k ausgeben
print(f"Best K: {grid_search.best_params_}")

# Vorhersagen auf den Testdaten
y_pred = grid_search.predict(X_test)

# Ergebnisse ausgeben
print(classification_report(y_test, y_pred))
# Out:
# Best K: {'kneighborsclassifier__n_neighbors': 22}
#               precision    recall  f1-score   support
#
#         Down       0.96      0.84      0.90       132
#           Up       0.84      0.96      0.90       118
#
#     accuracy                           0.90       250
#    macro avg       0.90      0.90      0.90       250
# weighted avg       0.90      0.90      0.90       250
